# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="197986623" href="javascript:toggle_input_197986623()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_197986623;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_197986623 = document.getElementById("197986623");
#                 var cell = link_197986623;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_197986623;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_197986623 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_197986623 = cell.previousElementSibling;
#                 }
#                 input_197986623.style.display = "none"; // hide
#
#                 toggle_input_197986623 = function() {
#                     if (input_197986623.style.display == "none") {
#                         input_197986623.style.display = ""; // show
#                         link_197986623.innerHTML = "Hide Input";
#                     } else {
#                         input_197986623.style.display = "none"; // hide
#                         link_197986623.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_197986623 = $("a[id='197986623']");
#                 var cell_197986623 = link_197986623.parents("div.cell:first");
#                 if (cell_197986623.length == 0) {
#                     cell_197986623 = link_197986623.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_197986623 = cell_197986623.children("div.input");
#                 if (input_197986623.length == 0) {
#                     input_197986623 = cell_197986623.prev("div.nbinput");
#                 }
#                 input_197986623.hide();
#
#                 toggle_input_197986623 = function() {
#                     if (input_197986623.is(':hidden')) {
#                         input_197986623.slideDown();
#                         link_197986623[0].innerHTML = "Hide Input";
#                     } else {
#                         input_197986623.slideUp();
#                         link_197986623[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="685362461" href="javascript:toggle_input_685362461()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_685362461;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_685362461 = document.getElementById("685362461");
#                 var cell = link_685362461;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_685362461;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_685362461 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_685362461 = cell.previousElementSibling;
#                 }
#                 input_685362461.style.display = "none"; // hide
#
#                 toggle_input_685362461 = function() {
#                     if (input_685362461.style.display == "none") {
#                         input_685362461.style.display = ""; // show
#                         link_685362461.innerHTML = "Hide Input";
#                     } else {
#                         input_685362461.style.display = "none"; // hide
#                         link_685362461.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_685362461 = $("a[id='685362461']");
#                 var cell_685362461 = link_685362461.parents("div.cell:first");
#                 if (cell_685362461.length == 0) {
#                     cell_685362461 = link_685362461.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_685362461 = cell_685362461.children("div.input");
#                 if (input_685362461.length == 0) {
#                     input_685362461 = cell_685362461.prev("div.nbinput");
#                 }
#                 input_685362461.hide();
#
#                 toggle_input_685362461 = function() {
#                     if (input_685362461.is(':hidden')) {
#                         input_685362461.slideDown();
#                         link_685362461[0].innerHTML = "Hide Input";
#                     } else {
#                         input_685362461.slideUp();
#                         link_685362461[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="104571388" href="javascript:toggle_input_104571388()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_104571388;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_104571388 = document.getElementById("104571388");
#                 var cell = link_104571388;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_104571388;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_104571388 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_104571388 = cell.previousElementSibling;
#                 }
#                 input_104571388.style.display = "none"; // hide
#
#                 toggle_input_104571388 = function() {
#                     if (input_104571388.style.display == "none") {
#                         input_104571388.style.display = ""; // show
#                         link_104571388.innerHTML = "Hide Input";
#                     } else {
#                         input_104571388.style.display = "none"; // hide
#                         link_104571388.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_104571388 = $("a[id='104571388']");
#                 var cell_104571388 = link_104571388.parents("div.cell:first");
#                 if (cell_104571388.length == 0) {
#                     cell_104571388 = link_104571388.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_104571388 = cell_104571388.children("div.input");
#                 if (input_104571388.length == 0) {
#                     input_104571388 = cell_104571388.prev("div.nbinput");
#                 }
#                 input_104571388.hide();
#
#                 toggle_input_104571388 = function() {
#                     if (input_104571388.is(':hidden')) {
#                         input_104571388.slideDown();
#                         link_104571388[0].innerHTML = "Hide Input";
#                     } else {
#                         input_104571388.slideUp();
#                         link_104571388[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="46335819" href="javascript:toggle_input_46335819()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_46335819;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_46335819 = document.getElementById("46335819");
#                 var cell = link_46335819;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_46335819;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_46335819 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_46335819 = cell.previousElementSibling;
#                 }
#                 input_46335819.style.display = "none"; // hide
#
#                 toggle_input_46335819 = function() {
#                     if (input_46335819.style.display == "none") {
#                         input_46335819.style.display = ""; // show
#                         link_46335819.innerHTML = "Hide Input";
#                     } else {
#                         input_46335819.style.display = "none"; // hide
#                         link_46335819.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_46335819 = $("a[id='46335819']");
#                 var cell_46335819 = link_46335819.parents("div.cell:first");
#                 if (cell_46335819.length == 0) {
#                     cell_46335819 = link_46335819.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_46335819 = cell_46335819.children("div.input");
#                 if (input_46335819.length == 0) {
#                     input_46335819 = cell_46335819.prev("div.nbinput");
#                 }
#                 input_46335819.hide();
#
#                 toggle_input_46335819 = function() {
#                     if (input_46335819.is(':hidden')) {
#                         input_46335819.slideDown();
#                         link_46335819[0].innerHTML = "Hide Input";
#                     } else {
#                         input_46335819.slideUp();
#                         link_46335819[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="2131256215" href="javascript:toggle_input_2131256215()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2131256215;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2131256215 = document.getElementById("2131256215");
#                 var cell = link_2131256215;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2131256215;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2131256215 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2131256215 = cell.previousElementSibling;
#                 }
#                 input_2131256215.style.display = "none"; // hide
#
#                 toggle_input_2131256215 = function() {
#                     if (input_2131256215.style.display == "none") {
#                         input_2131256215.style.display = ""; // show
#                         link_2131256215.innerHTML = "Hide Input";
#                     } else {
#                         input_2131256215.style.display = "none"; // hide
#                         link_2131256215.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2131256215 = $("a[id='2131256215']");
#                 var cell_2131256215 = link_2131256215.parents("div.cell:first");
#                 if (cell_2131256215.length == 0) {
#                     cell_2131256215 = link_2131256215.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2131256215 = cell_2131256215.children("div.input");
#                 if (input_2131256215.length == 0) {
#                     input_2131256215 = cell_2131256215.prev("div.nbinput");
#                 }
#                 input_2131256215.hide();
#
#                 toggle_input_2131256215 = function() {
#                     if (input_2131256215.is(':hidden')) {
#                         input_2131256215.slideDown();
#                         link_2131256215[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2131256215.slideUp();
#                         link_2131256215[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1669428474" href="javascript:toggle_input_1669428474()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1669428474;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1669428474 = document.getElementById("1669428474");
#                 var cell = link_1669428474;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1669428474;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1669428474 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1669428474 = cell.previousElementSibling;
#                 }
#                 input_1669428474.style.display = "none"; // hide
#
#                 toggle_input_1669428474 = function() {
#                     if (input_1669428474.style.display == "none") {
#                         input_1669428474.style.display = ""; // show
#                         link_1669428474.innerHTML = "Hide Input";
#                     } else {
#                         input_1669428474.style.display = "none"; // hide
#                         link_1669428474.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1669428474 = $("a[id='1669428474']");
#                 var cell_1669428474 = link_1669428474.parents("div.cell:first");
#                 if (cell_1669428474.length == 0) {
#                     cell_1669428474 = link_1669428474.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1669428474 = cell_1669428474.children("div.input");
#                 if (input_1669428474.length == 0) {
#                     input_1669428474 = cell_1669428474.prev("div.nbinput");
#                 }
#                 input_1669428474.hide();
#
#                 toggle_input_1669428474 = function() {
#                     if (input_1669428474.is(':hidden')) {
#                         input_1669428474.slideDown();
#                         link_1669428474[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1669428474.slideUp();
#                         link_1669428474[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="39232123" href="javascript:toggle_input_39232123()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_39232123;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_39232123 = document.getElementById("39232123");
#                 var cell = link_39232123;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_39232123;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_39232123 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_39232123 = cell.previousElementSibling;
#                 }
#                 input_39232123.style.display = "none"; // hide
#
#                 toggle_input_39232123 = function() {
#                     if (input_39232123.style.display == "none") {
#                         input_39232123.style.display = ""; // show
#                         link_39232123.innerHTML = "Hide Input";
#                     } else {
#                         input_39232123.style.display = "none"; // hide
#                         link_39232123.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_39232123 = $("a[id='39232123']");
#                 var cell_39232123 = link_39232123.parents("div.cell:first");
#                 if (cell_39232123.length == 0) {
#                     cell_39232123 = link_39232123.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_39232123 = cell_39232123.children("div.input");
#                 if (input_39232123.length == 0) {
#                     input_39232123 = cell_39232123.prev("div.nbinput");
#                 }
#                 input_39232123.hide();
#
#                 toggle_input_39232123 = function() {
#                     if (input_39232123.is(':hidden')) {
#                         input_39232123.slideDown();
#                         link_39232123[0].innerHTML = "Hide Input";
#                     } else {
#                         input_39232123.slideUp();
#                         link_39232123[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="696365219" href="javascript:toggle_input_696365219()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_696365219;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_696365219 = document.getElementById("696365219");
#                 var cell = link_696365219;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_696365219;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_696365219 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_696365219 = cell.previousElementSibling;
#                 }
#                 input_696365219.style.display = "none"; // hide
#
#                 toggle_input_696365219 = function() {
#                     if (input_696365219.style.display == "none") {
#                         input_696365219.style.display = ""; // show
#                         link_696365219.innerHTML = "Hide Input";
#                     } else {
#                         input_696365219.style.display = "none"; // hide
#                         link_696365219.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_696365219 = $("a[id='696365219']");
#                 var cell_696365219 = link_696365219.parents("div.cell:first");
#                 if (cell_696365219.length == 0) {
#                     cell_696365219 = link_696365219.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_696365219 = cell_696365219.children("div.input");
#                 if (input_696365219.length == 0) {
#                     input_696365219 = cell_696365219.prev("div.nbinput");
#                 }
#                 input_696365219.hide();
#
#                 toggle_input_696365219 = function() {
#                     if (input_696365219.is(':hidden')) {
#                         input_696365219.slideDown();
#                         link_696365219[0].innerHTML = "Hide Input";
#                     } else {
#                         input_696365219.slideUp();
#                         link_696365219[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1753336390" href="javascript:toggle_input_1753336390()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1753336390;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1753336390 = document.getElementById("1753336390");
#                 var cell = link_1753336390;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1753336390;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1753336390 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1753336390 = cell.previousElementSibling;
#                 }
#                 input_1753336390.style.display = "none"; // hide
#
#                 toggle_input_1753336390 = function() {
#                     if (input_1753336390.style.display == "none") {
#                         input_1753336390.style.display = ""; // show
#                         link_1753336390.innerHTML = "Hide Input";
#                     } else {
#                         input_1753336390.style.display = "none"; // hide
#                         link_1753336390.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1753336390 = $("a[id='1753336390']");
#                 var cell_1753336390 = link_1753336390.parents("div.cell:first");
#                 if (cell_1753336390.length == 0) {
#                     cell_1753336390 = link_1753336390.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1753336390 = cell_1753336390.children("div.input");
#                 if (input_1753336390.length == 0) {
#                     input_1753336390 = cell_1753336390.prev("div.nbinput");
#                 }
#                 input_1753336390.hide();
#
#                 toggle_input_1753336390 = function() {
#                     if (input_1753336390.is(':hidden')) {
#                         input_1753336390.slideDown();
#                         link_1753336390[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1753336390.slideUp();
#                         link_1753336390[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1834753481" href="javascript:toggle_input_1834753481()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1834753481;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1834753481 = document.getElementById("1834753481");
#                 var cell = link_1834753481;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1834753481;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1834753481 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1834753481 = cell.previousElementSibling;
#                 }
#                 input_1834753481.style.display = "none"; // hide
#
#                 toggle_input_1834753481 = function() {
#                     if (input_1834753481.style.display == "none") {
#                         input_1834753481.style.display = ""; // show
#                         link_1834753481.innerHTML = "Hide Input";
#                     } else {
#                         input_1834753481.style.display = "none"; // hide
#                         link_1834753481.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1834753481 = $("a[id='1834753481']");
#                 var cell_1834753481 = link_1834753481.parents("div.cell:first");
#                 if (cell_1834753481.length == 0) {
#                     cell_1834753481 = link_1834753481.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1834753481 = cell_1834753481.children("div.input");
#                 if (input_1834753481.length == 0) {
#                     input_1834753481 = cell_1834753481.prev("div.nbinput");
#                 }
#                 input_1834753481.hide();
#
#                 toggle_input_1834753481 = function() {
#                     if (input_1834753481.is(':hidden')) {
#                         input_1834753481.slideDown();
#                         link_1834753481[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1834753481.slideUp();
#                         link_1834753481[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="691985429" href="javascript:toggle_input_691985429()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_691985429;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_691985429 = document.getElementById("691985429");
#                 var cell = link_691985429;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_691985429;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_691985429 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_691985429 = cell.previousElementSibling;
#                 }
#                 input_691985429.style.display = "none"; // hide
#
#                 toggle_input_691985429 = function() {
#                     if (input_691985429.style.display == "none") {
#                         input_691985429.style.display = ""; // show
#                         link_691985429.innerHTML = "Hide Input";
#                     } else {
#                         input_691985429.style.display = "none"; // hide
#                         link_691985429.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_691985429 = $("a[id='691985429']");
#                 var cell_691985429 = link_691985429.parents("div.cell:first");
#                 if (cell_691985429.length == 0) {
#                     cell_691985429 = link_691985429.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_691985429 = cell_691985429.children("div.input");
#                 if (input_691985429.length == 0) {
#                     input_691985429 = cell_691985429.prev("div.nbinput");
#                 }
#                 input_691985429.hide();
#
#                 toggle_input_691985429 = function() {
#                     if (input_691985429.is(':hidden')) {
#                         input_691985429.slideDown();
#                         link_691985429[0].innerHTML = "Hide Input";
#                     } else {
#                         input_691985429.slideUp();
#                         link_691985429[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1688932020" href="javascript:toggle_input_1688932020()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1688932020;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1688932020 = document.getElementById("1688932020");
#                 var cell = link_1688932020;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1688932020;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1688932020 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1688932020 = cell.previousElementSibling;
#                 }
#                 input_1688932020.style.display = "none"; // hide
#
#                 toggle_input_1688932020 = function() {
#                     if (input_1688932020.style.display == "none") {
#                         input_1688932020.style.display = ""; // show
#                         link_1688932020.innerHTML = "Hide Input";
#                     } else {
#                         input_1688932020.style.display = "none"; // hide
#                         link_1688932020.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1688932020 = $("a[id='1688932020']");
#                 var cell_1688932020 = link_1688932020.parents("div.cell:first");
#                 if (cell_1688932020.length == 0) {
#                     cell_1688932020 = link_1688932020.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1688932020 = cell_1688932020.children("div.input");
#                 if (input_1688932020.length == 0) {
#                     input_1688932020 = cell_1688932020.prev("div.nbinput");
#                 }
#                 input_1688932020.hide();
#
#                 toggle_input_1688932020 = function() {
#                     if (input_1688932020.is(':hidden')) {
#                         input_1688932020.slideDown();
#                         link_1688932020[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1688932020.slideUp();
#                         link_1688932020[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="194297158" href="javascript:toggle_input_194297158()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_194297158;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_194297158 = document.getElementById("194297158");
#                 var cell = link_194297158;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_194297158;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_194297158 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_194297158 = cell.previousElementSibling;
#                 }
#                 input_194297158.style.display = "none"; // hide
#
#                 toggle_input_194297158 = function() {
#                     if (input_194297158.style.display == "none") {
#                         input_194297158.style.display = ""; // show
#                         link_194297158.innerHTML = "Hide Input";
#                     } else {
#                         input_194297158.style.display = "none"; // hide
#                         link_194297158.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_194297158 = $("a[id='194297158']");
#                 var cell_194297158 = link_194297158.parents("div.cell:first");
#                 if (cell_194297158.length == 0) {
#                     cell_194297158 = link_194297158.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_194297158 = cell_194297158.children("div.input");
#                 if (input_194297158.length == 0) {
#                     input_194297158 = cell_194297158.prev("div.nbinput");
#                 }
#                 input_194297158.hide();
#
#                 toggle_input_194297158 = function() {
#                     if (input_194297158.is(':hidden')) {
#                         input_194297158.slideDown();
#                         link_194297158[0].innerHTML = "Hide Input";
#                     } else {
#                         input_194297158.slideUp();
#                         link_194297158[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
